# %% [markdown]
# ### Exploratory Data Analysis

# %%
### Distbn, outliers, missing values, anomalies, identifying patterns, relationships

# %% [markdown]
# ### Distribution of a variable

# %% [markdown]
# ### Univariate --> one variable --> Measures of central tendency --> histogram, barchart, pie chart

# %% [markdown]
# ### Bivariate --> two --> relationship between variables --> scatterplot, pairplot

# %% [markdown]
# ### Multivariate--> more than two -->

# %%
### import the packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
## sns.set(style="whitegrid")
##sns.set(style="darkgrid")
##sns.set(style="dark")
sns.set(style="ticks")

# %%
df=pd.read_csv("auto-mpg.csv")

# %%
##df.head(5)
df.head().style.background_gradient(cmap="Dark2")
# Out:
# <style type="text/css">
# #T_acd28_row0_col0, #T_acd28_row0_col5, #T_acd28_row1_col2, #T_acd28_row1_col4, #T_acd28_row2_col0, #T_acd28_row3_col5 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_acd28_row0_col1, #T_acd28_row0_col2, #T_acd28_row0_col6, #T_acd28_row0_col7, #T_acd28_row1_col0, #T_acd28_row1_col1, #T_acd28_row1_col6, #T_acd28_row1_col7, #T_acd28_row2_col1, #T_acd28_row2_col4, #T_acd28_row2_col6, #T_acd28_row2_col7, #T_acd28_row3_col1, #T_acd28_row3_col2, #T_acd28_row3_col4, #T_acd28_row3_col6, #T_acd28_row3_col7, #T_acd28_row4_col1, #T_acd28_row4_col2, #T_acd28_row4_col4, #T_acd28_row4_col5, #T_acd28_row4_col6, #T_acd28_row4_col7 {
#   background-color: #1b9e77;
#   color: #f1f1f1;
# }
# #T_acd28_row0_col4, #T_acd28_row2_col2, #T_acd28_row2_col5, #T_acd28_row3_col0 {
#   background-color: #7570b3;
#   color: #f1f1f1;
# }
# #T_acd28_row1_col5, #T_acd28_row4_col0 {
#   background-color: #e6ab02;
#   color: #000000;
# }
# </style>
# <table id="T_acd28">
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.dtypes
# Out:
# mpg         float64
# cyl           int64
# disp        float64
# hp           object
# wt            int64
# acc         float64
# yr            int64
# origin        int64
# car name     object
# dtype: object

# %%
df
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin  \
# 0    18.0    8  307.0  130  3504  12.0  70       1
# 1    15.0    8  350.0  165  3693  11.5  70       1
# 2    18.0    8  318.0  150  3436  11.0  70       1
# 3    16.0    8  304.0  150  3433  12.0  70       1
# 4    17.0    8  302.0  140  3449  10.5  70       1
# 5    15.0    8  429.0  198  4341  10.0  70       1
# 6    14.0    8  454.0  220  4354   9.0  70       1
# 7    14.0    8  440.0  215  4312   8.5  70       1
# 8    14.0    8  455.0  225  4425  10.0  70       1
# 9    15.0    8  390.0  190  3850   8.5  70       1
# 10   15.0    8  383.0  170  3563  10.0  70       1
# 11   14.0    8  340.0  160  3609   8.0  70       1
# 12   15.0    8  400.0  150  3761   9.5  70       1
# 13   14.0    8  455.0  225  3086  10.0  70       1
# 14   24.0    4  113.0   95  2372  15.0  70       3
# 15   22.0    6  198.0   95  2833  15.5  70       1
# 16   18.0    6  199.0   97  2774  15.5  70       1
# ...

# %%
### Drop insignificant columns
df.drop("car name", axis=1, inplace=True)

# %%
df.describe(include="all")
## min value of month can't be zero
# Out:
#                mpg         cyl        disp   hp           wt         acc  \
# count   398.000000  398.000000  398.000000  398   398.000000  398.000000
# unique         NaN         NaN         NaN   94          NaN         NaN
# top            NaN         NaN         NaN  150          NaN         NaN
# freq           NaN         NaN         NaN   22          NaN         NaN
# mean     23.514573    5.454774  193.425879  NaN  2970.424623   15.568090
# std       7.815984    1.701004  104.269838  NaN   846.841774    2.757689
# min       9.000000    3.000000   68.000000  NaN  1613.000000    8.000000
# 25%      17.500000    4.000000  104.250000  NaN  2223.750000   13.825000
# 50%      23.000000    4.000000  148.500000  NaN  2803.500000   15.500000
# 75%      29.000000    8.000000  262.000000  NaN  3608.000000   17.175000
# max      46.600000    8.000000  455.000000  NaN  5140.000000   24.800000
#
#                 yr      origin
# count   398.000000  398.000000
# ...

# %%
df
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin
# 0    18.0    8  307.0  130  3504  12.0  70       1
# 1    15.0    8  350.0  165  3693  11.5  70       1
# 2    18.0    8  318.0  150  3436  11.0  70       1
# 3    16.0    8  304.0  150  3433  12.0  70       1
# 4    17.0    8  302.0  140  3449  10.5  70       1
# 5    15.0    8  429.0  198  4341  10.0  70       1
# 6    14.0    8  454.0  220  4354   9.0  70       1
# 7    14.0    8  440.0  215  4312   8.5  70       1
# 8    14.0    8  455.0  225  4425  10.0  70       1
# 9    15.0    8  390.0  190  3850   8.5  70       1
# 10   15.0    8  383.0  170  3563  10.0  70       1
# 11   14.0    8  340.0  160  3609   8.0  70       1
# 12   15.0    8  400.0  150  3761   9.5  70       1
# 13   14.0    8  455.0  225  3086  10.0  70       1
# 14   24.0    4  113.0   95  2372  15.0  70       3
# 15   22.0    6  198.0   95  2833  15.5  70       1
# 16   18.0    6  199.0   97  2774  15.5  70       1
# ...

# %%
df.describe()
# Out:
#               mpg         cyl        disp           wt         acc  \
# count  398.000000  398.000000  398.000000   398.000000  398.000000
# mean    23.514573    5.454774  193.425879  2970.424623   15.568090
# std      7.815984    1.701004  104.269838   846.841774    2.757689
# min      9.000000    3.000000   68.000000  1613.000000    8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000   13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000   17.175000
# max     46.600000    8.000000  455.000000  5140.000000   24.800000
#
#                yr      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     398 non-null    float64
#  1   cyl     398 non-null    int64
#  2   disp    398 non-null    float64
#  3   hp      398 non-null    object
#  4   wt      398 non-null    int64
#  5   acc     398 non-null    float64
#  6   yr      398 non-null    int64
#  7   origin  398 non-null    int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 25.0+ KB

# %%
sns.distplot(df["mpg"])
plt.show()
## As the curve is on left handside or most of data is distributed on left hand side, it is positively skewed

# %%
sns.distplot(df["cyl"])
plt.show()

# %%
sns.distplot(df["disp"])
plt.show()

# %%
sns.distplot(df["wt"])
plt.show()

# %%
sns.distplot(df["acc"])
plt.show()

# %%
sns.distplot(df["yr"])
plt.show()

# %%
sns.distplot(df["origin"])
plt.show()

# %%
# Categorical plot

# %%
df["hp"].value_counts()
# Out:
# hp
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
# 75     14
# 95     14
# 105    12
# 70     12
# 67     12
# 65     10
# 97      9
# 85      9
# 80      7
# 145     7
# 140     7
# 92      6
# 68      6
# 78      6
# 84      6
# ?       6
# 72      6
# 180     5
# 71      5
# 86      5
# 115     5
# 130     5
# 60      5
# 170     5
# 175     5
# 83      4
# 120     4
# 76      4
# 165     4
# 52      4
# 190     3
# 125     3
# 215     3
# 48      3
# 63      3
# 112     3
# 225     3
# 96      3
# 69      3
# 74      3
# 129     2
# 98      2
# 198     2
# 53      2
# 81      2
# 79      2
# 153     2
# 58      2
# 62      2
# 87      2
# 46      2
# 160     2
# 155     2
# 139     2
# 66      1
# 149     1
# 132     1
# 64      1
# 116     1
# 77      1
# 89      1
# 142     1
# 135     1
# 138     1
# 133     1
# 103     1
# 107     1
# 108     1
# 102     1
# 220     1
# 113     1
# 200     1
# 210     1
# 193     1
# 54      1
# 208     1
# 137     1
# ...

# %%
df["hp"].value_counts().plot(kind="bar")
plt.title("HP with Different Frequency")
plt.xlabel("hp")
plt.ylabel("Frequency")
plt.show()
